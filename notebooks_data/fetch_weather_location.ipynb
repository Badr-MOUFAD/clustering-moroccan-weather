# %%
# set root directory as the working directory
import os

os.chdir('../')
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\clustering-moroccan-weather-data'

# %%
# computation
import numpy as np
import pandas as pd

# %%
# imports for plots
from plotly import graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import plotly.io as pio

pio.templates.default = "plotly_white"

# %%
# fetch weather sidi sliman
# lat and lon for the location
lat , lon = 34.27315173279386, -5.948527875758534

# %%
# fetch data
from py_scripts.fetch import LocationWeather

weather_data = LocationWeather(lat, lon).weather_data_frame

# %%
# plot temperature
fig = px.line(weather_data, x="DATE", y="T2M_MAX")

fig.show()

# %%
from py_scripts.process import process_data

processed_data = process_data(weather_data)

# %%
# compare data
trusted_processed_data = pd.read_csv("raw_data/processed_weather_3.csv")

# %%
trusted_processed_data
# Out:
#              DATE  ALLSKY_SFC_SW_DWN  PRECTOT   RH2M    T2M  T2MDEW  T2M_MAX  \
# 0      1981-10-15             -99.00     0.20  27.83  25.73    5.07    35.07
# 1      1981-10-16             -99.00     0.14  46.26  23.85   11.38    30.86
# 2      1981-10-17             -99.00     0.06  52.67  22.69   12.19    30.74
# 3      1981-10-18             -99.00     0.28  37.36  25.51    9.55    32.46
# 4      1981-10-19             -99.00     0.02  28.48  27.13    6.88    35.23
# ...           ...                ...      ...    ...    ...     ...      ...
# 10486  2020-07-06              28.56     0.00  23.36  32.98    9.31    43.61
# 10487  2020-07-07              28.53     0.00  17.79  35.64    7.50    46.11
# 10488  2020-07-08              27.94     0.00  35.64  29.69   12.81    37.05
# 10489  2020-07-09              28.70     0.00  46.51  25.46   13.18    35.16
# 10490  2020-07-10              28.64     0.01  42.59  26.85   13.05    37.51
#
# ...

# %%
query = processed_data["crop_year"].isin(["1995", "2000", "2005"])
data_to_plot = processed_data[query]

fig = px.line(data_to_plot, x="day", y="cumulative_PRECTOT", color="crop_year")

fig.show()

# %%
# fetch data weather data of beni-mellal
from py_scripts.fetch import LocationWeather

lat, lon = 32.34577721752976, -6.349024662673606

weather_data_ben_mellal = LocationWeather(lat, lon).weather_data_frame

# %%
from py_scripts.process import process_data

processed_beni_mellal = process_data(weather_data_ben_mellal)

# %%
query = processed_beni_mellal["crop_year"].isin(["1995", "2000", "2005"])
data_to_plot = processed_beni_mellal[query]

fig = px.line(data_to_plot, x="day", y="cumulative_PRECTOT", color="crop_year")

fig.show()

# %%
# # save data beni-mellal
# weather_data_ben_mellal.to_csv("raw_data/beni_mellal.csv")

# %%
# save processed data beni mellal
# processed_beni_mellal.to_csv("processed_data/processed_beni_mellal.csv", index=False)
